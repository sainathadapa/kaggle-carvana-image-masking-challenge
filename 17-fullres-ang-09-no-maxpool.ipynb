# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-09-no-maxpool.ipynb#Load-libraries" data-toc-modified-id="Load-libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load libraries</a></span></li><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-09-no-maxpool.ipynb#Define-loss-functions" data-toc-modified-id="Define-loss-functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Define loss functions</a></span></li><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-09-no-maxpool.ipynb#Define-models" data-toc-modified-id="Define-models-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Define models</a></span></li><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-09-no-maxpool.ipynb#Training" data-toc-modified-id="Training-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Training</a></span><ul class="toc-item"><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-09-no-maxpool.ipynb#Functions,-generators-and-data" data-toc-modified-id="Functions,-generators-and-data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Functions, generators and data</a></span></li><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-09-no-maxpool.ipynb#Training" data-toc-modified-id="Training-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Training</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Load libraries

# %%
import cv2
import numpy as np
import pandas as pd

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, UpSampling2D, BatchNormalization
from keras.optimizers import RMSprop
from keras.losses import binary_crossentropy
import keras.backend as K

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
import math
import random
import gzip
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Define loss functions

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score


def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss


def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %% [markdown]
# # Define models

# %%
def unet_down_one_block(inputs, num_filters):
    x = Conv2D(num_filters, (3, 3), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def unet_max_pool(inputs):
    x = Conv2D(inputs.get_shape().as_list()[3],
               (2,2), strides=(2,2))(inputs)
    return x

# %%
def unet_up_one_block(up_input, down_input, num_filters):
    x = UpSampling2D((2,2))(up_input)
    x = concatenate([down_input, x], axis=3)
    x = Conv2D(num_filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def get_unet(input_shape = (256, 256, 3),
             num_classes = 1,
             initial_filters = 32,
             central_filters = 1024):
    
    num_filters = initial_filters
    
    out_list    = [Input(shape=input_shape)]
    down_interim_list = []
    
    while num_filters <= central_filters/2:
        x = unet_down_one_block(out_list[-1], num_filters)
        down_interim_list.append(x)
        num_filters = num_filters * 2
        y = unet_max_pool(x)
        out_list.append(y)
    
    x = unet_down_one_block(out_list[-1], num_filters)
    out_list.append(x)
    num_filters = int(num_filters / 2)
    
    while num_filters >= initial_filters:
        x = unet_up_one_block(out_list[-1], down_interim_list.pop(), num_filters)
        out_list.append(x)
        num_filters = int(num_filters / 2)
    
    classify = Conv2D(num_classes, (1,1), activation = 'sigmoid')(out_list[-1])
    
    model = Model(inputs=out_list[0], outputs=classify)
    
    return model

# %%
model = get_unet(input_shape=(896,1280,3), initial_filters=8)

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 896, 1280, 3)  0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 896, 1280, 8)  224         input_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 896, 1280, 8)  32          conv2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 896, 1280, 8)  0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 896, 1280, 8)  584         activation_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 896, 1280, 8)  32          conv2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 896, 1280, 8)  0           batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 448, 640, 8)   264         activation_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 448, 640, 16)  1168        conv2d_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 448, 640, 16)  64          conv2d_4[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 448, 640, 16)  0           batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 448, 640, 16)  2320        activation_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 448, 640, 16)  64          conv2d_5[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 448, 640, 16)  0           batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 224, 320, 16)  1040        activation_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 224, 320, 32)  4640        conv2d_6[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 224, 320, 32)  128         conv2d_7[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 224, 320, 32)  0           batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 224, 320, 32)  9248        activation_5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, 224, 320, 32)  128         conv2d_8[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 224, 320, 32)  0           batch_normalization_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 112, 160, 32)  4128        activation_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 112, 160, 64)  18496       conv2d_9[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNorm (None, 112, 160, 64)  256         conv2d_10[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 112, 160, 64)  0           batch_normalization_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 112, 160, 64)  36928       activation_7[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNorm (None, 112, 160, 64)  256         conv2d_11[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 112, 160, 64)  0           batch_normalization_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 56, 80, 64)    16448       activation_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 56, 80, 128)   73856       conv2d_12[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNorm (None, 56, 80, 128)   512         conv2d_13[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 56, 80, 128)   0           batch_normalization_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 56, 80, 128)   147584      activation_9[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10 (BatchNor (None, 56, 80, 128)   512         conv2d_14[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 56, 80, 128)   0           batch_normalization_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 28, 40, 128)   65664       activation_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 28, 40, 256)   295168      conv2d_15[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_11 (BatchNor (None, 28, 40, 256)   1024        conv2d_16[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 28, 40, 256)   0           batch_normalization_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 28, 40, 256)   590080      activation_11[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_12 (BatchNor (None, 28, 40, 256)   1024        conv2d_17[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 28, 40, 256)   0           batch_normalization_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 14, 20, 256)   262400      activation_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 14, 20, 512)   1180160     conv2d_18[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_13 (BatchNor (None, 14, 20, 512)   2048        conv2d_19[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 14, 20, 512)   0           batch_normalization_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 14, 20, 512)   2359808     activation_13[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_14 (BatchNor (None, 14, 20, 512)   2048        conv2d_20[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 14, 20, 512)   0           batch_normalization_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 7, 10, 512)    1049088     activation_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 7, 10, 1024)   4719616     conv2d_21[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_15 (BatchNor (None, 7, 10, 1024)   4096        conv2d_22[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 7, 10, 1024)   0           batch_normalization_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 7, 10, 1024)   9438208     activation_15[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_16 (BatchNor (None, 7, 10, 1024)   4096        conv2d_23[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 7, 10, 1024)   0           batch_normalization_16[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 14, 20, 1024)  0           activation_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 14, 20, 1536)  0           activation_14[0][0]
#                                                                    up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 14, 20, 512)   7078400     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_17 (BatchNor (None, 14, 20, 512)   2048        conv2d_24[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 14, 20, 512)   0           batch_normalization_17[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 14, 20, 512)   2359808     activation_17[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_18 (BatchNor (None, 14, 20, 512)   2048        conv2d_25[0][0]
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, 14, 20, 512)   0           batch_normalization_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 14, 20, 512)   2359808     activation_18[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_19 (BatchNor (None, 14, 20, 512)   2048        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 14, 20, 512)   0           batch_normalization_19[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 28, 40, 512)   0           activation_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 28, 40, 768)   0           activation_12[0][0]
#                                                                    up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 28, 40, 256)   1769728     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_20 (BatchNor (None, 28, 40, 256)   1024        conv2d_27[0][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 28, 40, 256)   0           batch_normalization_20[0][0]
# ____________________________________________________________________________________________________
# conv2d_28 (Conv2D)               (None, 28, 40, 256)   590080      activation_20[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_21 (BatchNor (None, 28, 40, 256)   1024        conv2d_28[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 28, 40, 256)   0           batch_normalization_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_29 (Conv2D)               (None, 28, 40, 256)   590080      activation_21[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_22 (BatchNor (None, 28, 40, 256)   1024        conv2d_29[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 28, 40, 256)   0           batch_normalization_22[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 56, 80, 256)   0           activation_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 56, 80, 384)   0           activation_10[0][0]
#                                                                    up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_30 (Conv2D)               (None, 56, 80, 128)   442496      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_23 (BatchNor (None, 56, 80, 128)   512         conv2d_30[0][0]
# ____________________________________________________________________________________________________
# activation_23 (Activation)       (None, 56, 80, 128)   0           batch_normalization_23[0][0]
# ____________________________________________________________________________________________________
# conv2d_31 (Conv2D)               (None, 56, 80, 128)   147584      activation_23[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_24 (BatchNor (None, 56, 80, 128)   512         conv2d_31[0][0]
# ____________________________________________________________________________________________________
# activation_24 (Activation)       (None, 56, 80, 128)   0           batch_normalization_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_32 (Conv2D)               (None, 56, 80, 128)   147584      activation_24[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_25 (BatchNor (None, 56, 80, 128)   512         conv2d_32[0][0]
# ____________________________________________________________________________________________________
# activation_25 (Activation)       (None, 56, 80, 128)   0           batch_normalization_25[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 112, 160, 128) 0           activation_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 112, 160, 192) 0           activation_8[0][0]
#                                                                    up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_33 (Conv2D)               (None, 112, 160, 64)  110656      concatenate_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_26 (BatchNor (None, 112, 160, 64)  256         conv2d_33[0][0]
# ____________________________________________________________________________________________________
# activation_26 (Activation)       (None, 112, 160, 64)  0           batch_normalization_26[0][0]
# ____________________________________________________________________________________________________
# conv2d_34 (Conv2D)               (None, 112, 160, 64)  36928       activation_26[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_27 (BatchNor (None, 112, 160, 64)  256         conv2d_34[0][0]
# ____________________________________________________________________________________________________
# activation_27 (Activation)       (None, 112, 160, 64)  0           batch_normalization_27[0][0]
# ____________________________________________________________________________________________________
# conv2d_35 (Conv2D)               (None, 112, 160, 64)  36928       activation_27[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_28 (BatchNor (None, 112, 160, 64)  256         conv2d_35[0][0]
# ____________________________________________________________________________________________________
# activation_28 (Activation)       (None, 112, 160, 64)  0           batch_normalization_28[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 224, 320, 64)  0           activation_28[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 224, 320, 96)  0           activation_6[0][0]
#                                                                    up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_36 (Conv2D)               (None, 224, 320, 32)  27680       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_29 (BatchNor (None, 224, 320, 32)  128         conv2d_36[0][0]
# ____________________________________________________________________________________________________
# activation_29 (Activation)       (None, 224, 320, 32)  0           batch_normalization_29[0][0]
# ____________________________________________________________________________________________________
# conv2d_37 (Conv2D)               (None, 224, 320, 32)  9248        activation_29[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_30 (BatchNor (None, 224, 320, 32)  128         conv2d_37[0][0]
# ____________________________________________________________________________________________________
# activation_30 (Activation)       (None, 224, 320, 32)  0           batch_normalization_30[0][0]
# ____________________________________________________________________________________________________
# conv2d_38 (Conv2D)               (None, 224, 320, 32)  9248        activation_30[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_31 (BatchNor (None, 224, 320, 32)  128         conv2d_38[0][0]
# ____________________________________________________________________________________________________
# activation_31 (Activation)       (None, 224, 320, 32)  0           batch_normalization_31[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)   (None, 448, 640, 32)  0           activation_31[0][0]
# ____________________________________________________________________________________________________
# concatenate_6 (Concatenate)      (None, 448, 640, 48)  0           activation_4[0][0]
#                                                                    up_sampling2d_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_39 (Conv2D)               (None, 448, 640, 16)  6928        concatenate_6[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_32 (BatchNor (None, 448, 640, 16)  64          conv2d_39[0][0]
# ____________________________________________________________________________________________________
# activation_32 (Activation)       (None, 448, 640, 16)  0           batch_normalization_32[0][0]
# ____________________________________________________________________________________________________
# conv2d_40 (Conv2D)               (None, 448, 640, 16)  2320        activation_32[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_33 (BatchNor (None, 448, 640, 16)  64          conv2d_40[0][0]
# ____________________________________________________________________________________________________
# activation_33 (Activation)       (None, 448, 640, 16)  0           batch_normalization_33[0][0]
# ____________________________________________________________________________________________________
# conv2d_41 (Conv2D)               (None, 448, 640, 16)  2320        activation_33[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_34 (BatchNor (None, 448, 640, 16)  64          conv2d_41[0][0]
# ____________________________________________________________________________________________________
# activation_34 (Activation)       (None, 448, 640, 16)  0           batch_normalization_34[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)   (None, 896, 1280, 16) 0           activation_34[0][0]
# ____________________________________________________________________________________________________
# concatenate_7 (Concatenate)      (None, 896, 1280, 24) 0           activation_2[0][0]
#                                                                    up_sampling2d_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_42 (Conv2D)               (None, 896, 1280, 8)  1736        concatenate_7[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_35 (BatchNor (None, 896, 1280, 8)  32          conv2d_42[0][0]
# ____________________________________________________________________________________________________
# activation_35 (Activation)       (None, 896, 1280, 8)  0           batch_normalization_35[0][0]
# ____________________________________________________________________________________________________
# conv2d_43 (Conv2D)               (None, 896, 1280, 8)  584         activation_35[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_36 (BatchNor (None, 896, 1280, 8)  32          conv2d_43[0][0]
# ____________________________________________________________________________________________________
# activation_36 (Activation)       (None, 896, 1280, 8)  0           batch_normalization_36[0][0]
# ____________________________________________________________________________________________________
# conv2d_44 (Conv2D)               (None, 896, 1280, 8)  584         activation_36[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_37 (BatchNor (None, 896, 1280, 8)  32          conv2d_44[0][0]
# ____________________________________________________________________________________________________
# activation_37 (Activation)       (None, 896, 1280, 8)  0           batch_normalization_37[0][0]
# ____________________________________________________________________________________________________
# conv2d_45 (Conv2D)               (None, 896, 1280, 1)  9           activation_37[0][0]
# ====================================================================================================
# Total params: 36,036,369
# Trainable params: 36,022,113
# Non-trainable params: 14,256
# ____________________________________________________________________________________________________

# %% [markdown]
# # Training

# %% [markdown]
# ## Functions, generators and data

# %%
df_train = pd.read_csv('data/train_masks.csv')

# %%
df_train.head()
# Out:
#                    img                                           rle_mask
# 0  00087a6bd4dc_01.jpg  879386 40 881253 141 883140 205 885009 17 8850...
# 1  00087a6bd4dc_02.jpg  873779 4 875695 7 877612 9 879528 12 881267 15...
# 2  00087a6bd4dc_03.jpg  864300 9 866217 13 868134 15 870051 16 871969 ...
# 3  00087a6bd4dc_04.jpg  879735 20 881650 26 883315 92 883564 30 885208...
# 4  00087a6bd4dc_05.jpg  883365 74 883638 28 885262 119 885550 34 88716...

# %%
train_bboxes = pickle.load(open('./train_bboxes_resized_m512_ang_09.pkl', 'rb'))

# %%
actual_bboxes = pickle.load(open('./train_bboxes_actuals.pkl', 'rb'))

# %%
ids_train = list(train_bboxes.keys())

# %%
ids_train_split, ids_valid_split = train_test_split(ids_train, test_size=0.2, random_state=42)

# %%
def randomHueSaturationValue(image, hue_shift_limit=(-180, 180),
                             sat_shift_limit=(-255, 255),
                             val_shift_limit=(-255, 255), u=0.5):
    if np.random.random() < u:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        h, s, v = cv2.split(image)
        hue_shift = np.random.uniform(hue_shift_limit[0], hue_shift_limit[1])
        h = cv2.add(h, hue_shift)
        sat_shift = np.random.uniform(sat_shift_limit[0], sat_shift_limit[1])
        s = cv2.add(s, sat_shift)
        val_shift = np.random.uniform(val_shift_limit[0], val_shift_limit[1])
        v = cv2.add(v, val_shift)
        image = cv2.merge((h, s, v))
        image = cv2.cvtColor(image, cv2.COLOR_HSV2BGR)

    return image

# %%
def randomShiftScaleRotate(image, mask,
                           shift_limit=(-0.0625, 0.0625),
                           scale_limit=(-0.1, 0.1),
                           rotate_limit=(-45, 45), aspect_limit=(0, 0),
                           borderMode=cv2.BORDER_CONSTANT, u=0.5):
    if np.random.random() < u:
        height, width, channel = image.shape

        angle = np.random.uniform(rotate_limit[0], rotate_limit[1])  # degree
        scale = np.random.uniform(1 + scale_limit[0], 1 + scale_limit[1])
        aspect = np.random.uniform(1 + aspect_limit[0], 1 + aspect_limit[1])
        sx = scale * aspect / (aspect ** 0.5)
        sy = scale / (aspect ** 0.5)
        dx = round(np.random.uniform(shift_limit[0], shift_limit[1]) * width)
        dy = round(np.random.uniform(shift_limit[0], shift_limit[1]) * height)

        cc = np.math.cos(angle / 180 * np.math.pi) * sx
        ss = np.math.sin(angle / 180 * np.math.pi) * sy
        rotate_matrix = np.array([[cc, -ss], [ss, cc]])

        box0 = np.array([[0, 0], [width, 0], [width, height], [0, height], ])
        box1 = box0 - np.array([width / 2, height / 2])
        box1 = np.dot(box1, rotate_matrix.T) + np.array([width / 2 + dx, height / 2 + dy])

        box0 = box0.astype(np.float32)
        box1 = box1.astype(np.float32)
        mat = cv2.getPerspectiveTransform(box0, box1)
        image = cv2.warpPerspective(image, mat, (width, height), flags=cv2.INTER_LINEAR, borderMode=borderMode,
                                    borderValue=(
                                        0, 0,
                                        0,))
        mask = cv2.warpPerspective(mask, mat, (width, height), flags=cv2.INTER_LINEAR, borderMode=borderMode,
                                   borderValue=(
                                       0, 0,
                                       0,))

    return image, mask

# %%
def randomHorizontalFlip(image, mask, u=0.5):
    if np.random.random() < u:
        image = cv2.flip(image, 1)
        mask = cv2.flip(mask, 1)

    return image, mask

# %%
all_imgs  = {}
all_masks = {}
for id in ids_train:
    img  = cv2.imread('data/train/{}.jpg'.format(id))
    mask = cv2.imread('data/train_masks/{}_mask.png'.format(id), cv2.IMREAD_GRAYSCALE)
    all_imgs[id]  = img
    all_masks[id] = mask

# %%
def train_generator(train_batch_size):
    while True:
        this_ids_train_split = random.sample(ids_train_split, len(ids_train_split))
        for start in range(0, len(ids_train_split), train_batch_size):
            x_batch = []
            y_batch = []
            end = min(start + train_batch_size, len(ids_train_split))
            ids_train_batch = this_ids_train_split[start:end]
            for id in ids_train_batch:
                img  = all_imgs[id]
                mask = all_masks[id]
                
                this_bbox = train_bboxes[id]
                this_bbox = [math.floor(this_bbox[0]-25), math.ceil(this_bbox[1]+25),
                             math.floor(this_bbox[2]-20), math.ceil(this_bbox[3]+10)]
                
                x_size = this_bbox[1]-this_bbox[0]+1
                y_size = this_bbox[3]-this_bbox[2]+1
                
                x_diff=1280-x_size
                y_diff=896-y_size
                
                x_top=random.randint(0, min(x_diff, this_bbox[0]))
                x_bottom=min(x_diff-x_top, 1917-this_bbox[1])
                if (x_top+x_bottom) < x_diff:
                    if x_top==this_bbox[0]:
                        x_bottom = x_diff-x_top
                    else:
                        x_top = x_diff-x_bottom
                
                
                y_top=random.randint(0, min(y_diff, this_bbox[2]))
                y_bottom=min(y_diff-y_top, 1279-this_bbox[3])
                if (y_top+y_bottom) < y_diff:
                    if y_top==this_bbox[2]:
                        y_bottom = y_diff-y_top
                    else:
                        y_top = y_diff-y_bottom
                
                this_bbox[0] = this_bbox[0]-x_top
                this_bbox[1] = this_bbox[1]+x_bottom
                this_bbox[2] = this_bbox[2]-y_top
                this_bbox[3] = this_bbox[3]+y_bottom
                
                img  = img[this_bbox[2]:(this_bbox[3]+1), this_bbox[0]:(this_bbox[1]+1),:]
                mask = mask[this_bbox[2]:(this_bbox[3]+1), this_bbox[0]:(this_bbox[1]+1)]
                
                img = randomHueSaturationValue(img,
                                               hue_shift_limit=(-50, 50),
                                               sat_shift_limit=(-5, 5),
                                               val_shift_limit=(-15, 15))
                img, mask = randomHorizontalFlip(img, mask)
                
                mask = np.expand_dims(mask, axis=2)
                
                if img.shape[0]!=896 or img.shape[1]!=1280:
                    print(id)
                    print(x_top)
                    print(x_bottom)
                    print(y_top)
                    print(y_bottom)
                    print(x_diff)
                    print(y_diff)
                
                x_batch.append(img)
                y_batch.append(mask)
                
            x_batch = np.array(x_batch, np.float32) / 255
            y_batch = np.array(y_batch, np.float32) / 255
            yield x_batch, y_batch

# %%
def valid_generator(val_batch_size):
    while True:
        for start in range(0, len(ids_valid_split), val_batch_size):
            
            x_batch = []
            y_batch = []
            
            end = min(start + val_batch_size, len(ids_valid_split))
            ids_valid_batch = ids_valid_split[start:end]
            for id in ids_valid_batch:
                img  = all_imgs[id]
                mask = all_masks[id]
                
                this_bbox = list(actual_bboxes[id])
                
                x_size = this_bbox[1]-this_bbox[0]+1
                y_size = this_bbox[3]-this_bbox[2]+1
                
                x_diff=1280-x_size
                y_diff=896-y_size
                
                x_top=min(int(x_diff/2), this_bbox[0])
                x_bottom=min(x_diff-x_top, 1917-this_bbox[1])
                if (x_top+x_bottom) < x_diff:
                    if x_top==this_bbox[0]:
                        x_bottom = x_diff-x_top
                    else:
                        x_top = x_diff-x_bottom
                
                y_top=min(int(y_diff/2), this_bbox[2])
                y_bottom=min(y_diff-y_top, 1279-this_bbox[3])
                if (y_top+y_bottom) < y_diff:
                    if y_top==this_bbox[2]:
                        y_bottom = y_diff-y_top
                    else:
                        y_top = y_diff-y_bottom
                
                this_bbox[0] = this_bbox[0]-x_top
                this_bbox[1] = this_bbox[1]+x_bottom
                this_bbox[2] = this_bbox[2]-y_top
                this_bbox[3] = this_bbox[3]+y_bottom
                
                img  = img[this_bbox[2]:(this_bbox[3]+1), this_bbox[0]:(this_bbox[1]+1),:]
                mask = mask[this_bbox[2]:(this_bbox[3]+1), this_bbox[0]:(this_bbox[1]+1)]
                
                mask = np.expand_dims(mask, axis=2)
                
                x_batch.append(img)
                y_batch.append(mask)  
            x_batch = np.array(x_batch, np.float32) / 255
            y_batch = np.array(y_batch, np.float32) / 255
            yield x_batch, y_batch

# %% [markdown]
# ## Training

# %%
train_batch_size = 6
val_batch_size   = 16

# %%
max_epochs = 50

# %%
model.compile(optimizer=RMSprop(lr=0.01), loss=bce_dice_loss, metrics=[dice_coeff])

# %%
callbacks = [EarlyStopping(monitor='val_loss',
                           patience=8,
                           verbose=1,
                           min_delta=1e-4),
             ReduceLROnPlateau(monitor='val_loss',
                               factor=0.1,
                               patience=4,
                               verbose=1,
                               epsilon=1e-4),
             ModelCheckpoint(monitor='val_loss',
                             filepath='weights/full_res_ang_09_no_pool.hdf5',
                             save_best_only=True,
                             save_weights_only=True),
             TensorBoard(log_dir='logs')]

history = model.fit_generator(generator=train_generator(train_batch_size),
                    steps_per_epoch=np.ceil(float(len(ids_train_split)) / float(train_batch_size)),
                    epochs=max_epochs,
                    verbose=2,
                    callbacks=callbacks,
                    validation_data=valid_generator(val_batch_size),
                    validation_steps=np.ceil(float(len(ids_valid_split)) / float(val_batch_size)))
# Out:
# Epoch 1/50
# 159s - loss: 0.9916 - dice_coeff: 0.5406 - val_loss: 6.1407 - val_dice_coeff: 1.7103e-07
# Epoch 2/50
# 158s - loss: 0.6134 - dice_coeff: 0.7247 - val_loss: 6.9564 - val_dice_coeff: 0.2092
# Epoch 3/50
# 159s - loss: 0.4269 - dice_coeff: 0.8184 - val_loss: 9.0735 - val_dice_coeff: 0.5381
# Epoch 4/50
# 160s - loss: 0.3468 - dice_coeff: 0.8560 - val_loss: 11.3655 - val_dice_coeff: 0.4836
# Epoch 5/50
# 160s - loss: 0.2590 - dice_coeff: 0.8923 - val_loss: 9.3967 - val_dice_coeff: 0.5277
# Epoch 6/50
#
# Epoch 00005: reducing learning rate to 0.0009999999776482583.
# 160s - loss: 0.1926 - dice_coeff: 0.9204 - val_loss: 10.3039 - val_dice_coeff: 0.4969
# Epoch 7/50
# 160s - loss: 0.1576 - dice_coeff: 0.9373 - val_loss: 10.4788 - val_dice_coeff: 0.4918
# Epoch 8/50
# 160s - loss: 0.1308 - dice_coeff: 0.9439 - val_loss: 6.3177 - val_dice_coeff: 0.5975
# Epoch 9/50
# 160s - loss: 0.1189 - dice_coeff: 0.9496 - val_loss: 1.8677 - val_dice_coeff: 0.7798
# Epoch 10/50
# 160s - loss: 0.1199 - dice_coeff: 0.9497 - val_loss: 4.6771 - val_dice_coeff: 0.6032
# Epoch 11/50
# 160s - loss: 0.1162 - dice_coeff: 0.9506 - val_loss: 0.6802 - val_dice_coeff: 0.8498
# Epoch 12/50
# 160s - loss: 0.1094 - dice_coeff: 0.9539 - val_loss: 0.5003 - val_dice_coeff: 0.8689
# Epoch 13/50
# 160s - loss: 0.0983 - dice_coeff: 0.9584 - val_loss: 0.2268 - val_dice_coeff: 0.9243
# Epoch 14/50
# 160s - loss: 0.0978 - dice_coeff: 0.9587 - val_loss: 0.2048 - val_dice_coeff: 0.9320
# Epoch 15/50
# 160s - loss: 0.1013 - dice_coeff: 0.9582 - val_loss: 0.7327 - val_dice_coeff: 0.7761
# Epoch 16/50
# 160s - loss: 0.0936 - dice_coeff: 0.9604 - val_loss: 0.5600 - val_dice_coeff: 0.8066
# Epoch 17/50
# 160s - loss: 0.0931 - dice_coeff: 0.9609 - val_loss: 0.1107 - val_dice_coeff: 0.9500
# Epoch 18/50
# 160s - loss: 0.0819 - dice_coeff: 0.9650 - val_loss: 0.0859 - val_dice_coeff: 0.9592
# Epoch 19/50
# 160s - loss: 0.0836 - dice_coeff: 0.9650 - val_loss: 0.0951 - val_dice_coeff: 0.9590
# Epoch 20/50
# 160s - loss: 0.0856 - dice_coeff: 0.9642 - val_loss: 0.1698 - val_dice_coeff: 0.9407
# Epoch 21/50
# 160s - loss: 0.0762 - dice_coeff: 0.9678 - val_loss: 0.0924 - val_dice_coeff: 0.9584
# Epoch 22/50
# 160s - loss: 0.0758 - dice_coeff: 0.9687 - val_loss: 0.0852 - val_dice_coeff: 0.9620
# Epoch 23/50
# 160s - loss: 0.0730 - dice_coeff: 0.9692 - val_loss: 0.0700 - val_dice_coeff: 0.9672
# Epoch 24/50
# 160s - loss: 0.0744 - dice_coeff: 0.9694 - val_loss: 0.1745 - val_dice_coeff: 0.9384
# Epoch 25/50
# 160s - loss: 0.0707 - dice_coeff: 0.9705 - val_loss: 0.0819 - val_dice_coeff: 0.9644
# Epoch 26/50
# 160s - loss: 0.0711 - dice_coeff: 0.9704 - val_loss: 0.1004 - val_dice_coeff: 0.9570
# Epoch 27/50
# 160s - loss: 0.0668 - dice_coeff: 0.9721 - val_loss: 0.2680 - val_dice_coeff: 0.8880
# Epoch 28/50
# 160s - loss: 0.0617 - dice_coeff: 0.9740 - val_loss: 0.0689 - val_dice_coeff: 0.9697
# Epoch 29/50
# 160s - loss: 0.0612 - dice_coeff: 0.9745 - val_loss: 0.0934 - val_dice_coeff: 0.9630
# Epoch 30/50
# 160s - loss: 0.0636 - dice_coeff: 0.9742 - val_loss: 0.0814 - val_dice_coeff: 0.9640
# Epoch 31/50
# 160s - loss: 0.0590 - dice_coeff: 0.9750 - val_loss: 0.0779 - val_dice_coeff: 0.9653
# Epoch 32/50
# 160s - loss: 0.0547 - dice_coeff: 0.9770 - val_loss: 0.0785 - val_dice_coeff: 0.9687
# Epoch 33/50
# 160s - loss: 0.0585 - dice_coeff: 0.9762 - val_loss: 0.0624 - val_dice_coeff: 0.9738
# Epoch 34/50
# 160s - loss: 0.0538 - dice_coeff: 0.9774 - val_loss: 0.0892 - val_dice_coeff: 0.9648
# Epoch 35/50
# 160s - loss: 0.0559 - dice_coeff: 0.9768 - val_loss: 0.0737 - val_dice_coeff: 0.9702
# Epoch 36/50
# 160s - loss: 0.0500 - dice_coeff: 0.9791 - val_loss: 0.0740 - val_dice_coeff: 0.9708
# Epoch 37/50
# 160s - loss: 0.0509 - dice_coeff: 0.9789 - val_loss: 0.0751 - val_dice_coeff: 0.9711
# Epoch 38/50
# 160s - loss: 0.0525 - dice_coeff: 0.9785 - val_loss: 0.0571 - val_dice_coeff: 0.9762
# Epoch 39/50
# 160s - loss: 0.0477 - dice_coeff: 0.9801 - val_loss: 0.0600 - val_dice_coeff: 0.9744
# Epoch 40/50
# 160s - loss: 0.0489 - dice_coeff: 0.9796 - val_loss: 0.0995 - val_dice_coeff: 0.9640
# Epoch 41/50
# 160s - loss: 0.0467 - dice_coeff: 0.9805 - val_loss: 0.0679 - val_dice_coeff: 0.9717
# Epoch 42/50
# 160s - loss: 0.0441 - dice_coeff: 0.9814 - val_loss: 0.0567 - val_dice_coeff: 0.9773
# Epoch 43/50
# 160s - loss: 0.0445 - dice_coeff: 0.9815 - val_loss: 0.0558 - val_dice_coeff: 0.9788
# Epoch 44/50
# 160s - loss: 0.0468 - dice_coeff: 0.9806 - val_loss: 0.0690 - val_dice_coeff: 0.9735
# Epoch 45/50
# 161s - loss: 0.0439 - dice_coeff: 0.9816 - val_loss: 0.0521 - val_dice_coeff: 0.9790
# Epoch 46/50
# 160s - loss: 0.0441 - dice_coeff: 0.9817 - val_loss: 0.1776 - val_dice_coeff: 0.9534
# Epoch 47/50
# 160s - loss: 0.0445 - dice_coeff: 0.9817 - val_loss: 0.1102 - val_dice_coeff: 0.9640
# Epoch 48/50
# 160s - loss: 0.0417 - dice_coeff: 0.9826 - val_loss: 0.0551 - val_dice_coeff: 0.9774
# Epoch 49/50
# 160s - loss: 0.0439 - dice_coeff: 0.9821 - val_loss: 0.0483 - val_dice_coeff: 0.9799
# Epoch 50/50
# 160s - loss: 0.0379 - dice_coeff: 0.9840 - val_loss: 0.0604 - val_dice_coeff: 0.9786

# %%
callbacks = [EarlyStopping(monitor='val_loss',
                           patience=8,
                           verbose=1,
                           min_delta=1e-4),
             ReduceLROnPlateau(monitor='val_loss',
                               factor=0.1,
                               patience=4,
                               verbose=1,
                               epsilon=1e-4),
             ModelCheckpoint(monitor='val_loss',
                             filepath='weights/full_res_ang_09_no_pool.hdf5',
                             save_best_only=True,
                             save_weights_only=True),
             TensorBoard(log_dir='logs')]

history = model.fit_generator(generator=train_generator(train_batch_size),
                    steps_per_epoch=np.ceil(float(len(ids_train_split)) / float(train_batch_size)),
                    epochs=max_epochs,
                    verbose=2,
                    callbacks=callbacks,
                    validation_data=valid_generator(val_batch_size),
                    validation_steps=np.ceil(float(len(ids_valid_split)) / float(val_batch_size)))
# Out:
# Epoch 1/50
# 159s - loss: 0.0416 - dice_coeff: 0.9828 - val_loss: 0.0742 - val_dice_coeff: 0.9741
# Epoch 2/50
# 160s - loss: 0.0398 - dice_coeff: 0.9835 - val_loss: 0.0740 - val_dice_coeff: 0.9720
# Epoch 3/50
# 160s - loss: 0.0402 - dice_coeff: 0.9834 - val_loss: 0.0995 - val_dice_coeff: 0.9643
# Epoch 4/50
# 160s - loss: 0.0415 - dice_coeff: 0.9829 - val_loss: 0.0497 - val_dice_coeff: 0.9802
# Epoch 5/50
# 160s - loss: 0.0374 - dice_coeff: 0.9843 - val_loss: 0.0525 - val_dice_coeff: 0.9799
# Epoch 6/50
# 160s - loss: 0.0387 - dice_coeff: 0.9839 - val_loss: 0.0481 - val_dice_coeff: 0.9806
# Epoch 7/50
# 160s - loss: 0.0370 - dice_coeff: 0.9845 - val_loss: 0.0579 - val_dice_coeff: 0.9773
# Epoch 8/50
# 160s - loss: 0.0350 - dice_coeff: 0.9853 - val_loss: 0.0590 - val_dice_coeff: 0.9795
# Epoch 9/50
# 160s - loss: 0.0395 - dice_coeff: 0.9840 - val_loss: 0.0896 - val_dice_coeff: 0.9653
# Epoch 10/50
# 160s - loss: 0.0377 - dice_coeff: 0.9846 - val_loss: 0.1005 - val_dice_coeff: 0.9695
# Epoch 11/50
#
# Epoch 00010: reducing learning rate to 9.999999310821295e-05.
# 160s - loss: 0.0371 - dice_coeff: 0.9850 - val_loss: 0.0781 - val_dice_coeff: 0.9745
# Epoch 12/50
# 160s - loss: 0.0332 - dice_coeff: 0.9863 - val_loss: 0.0410 - val_dice_coeff: 0.9844
# Epoch 13/50
# 160s - loss: 0.0292 - dice_coeff: 0.9876 - val_loss: 0.0394 - val_dice_coeff: 0.9848
# Epoch 14/50
# 160s - loss: 0.0298 - dice_coeff: 0.9874 - val_loss: 0.0399 - val_dice_coeff: 0.9846
# Epoch 15/50
# 160s - loss: 0.0294 - dice_coeff: 0.9876 - val_loss: 0.0415 - val_dice_coeff: 0.9842
# Epoch 16/50
# 160s - loss: 0.0287 - dice_coeff: 0.9879 - val_loss: 0.0408 - val_dice_coeff: 0.9843
# Epoch 17/50
# 160s - loss: 0.0323 - dice_coeff: 0.9869 - val_loss: 0.0417 - val_dice_coeff: 0.9842
# Epoch 18/50
#
# Epoch 00017: reducing learning rate to 9.999999019782991e-06.
# 160s - loss: 0.0285 - dice_coeff: 0.9879 - val_loss: 0.0416 - val_dice_coeff: 0.9841
# Epoch 19/50
# 160s - loss: 0.0286 - dice_coeff: 0.9878 - val_loss: 0.0419 - val_dice_coeff: 0.9842
# Epoch 20/50
# 160s - loss: 0.0283 - dice_coeff: 0.9879 - val_loss: 0.0421 - val_dice_coeff: 0.9843
# Epoch 21/50
# 160s - loss: 0.0286 - dice_coeff: 0.9879 - val_loss: 0.0419 - val_dice_coeff: 0.9844
# Epoch 22/50
#
# Epoch 00021: reducing learning rate to 9.99999883788405e-07.
# 160s - loss: 0.0283 - dice_coeff: 0.9880 - val_loss: 0.0417 - val_dice_coeff: 0.9844
# Epoch 00021: early stopping
