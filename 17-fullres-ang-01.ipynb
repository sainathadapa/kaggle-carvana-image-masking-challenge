# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-01.ipynb#Load-libraries" data-toc-modified-id="Load-libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load libraries</a></span></li><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-01.ipynb#Define-loss-functions" data-toc-modified-id="Define-loss-functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Define loss functions</a></span></li><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-01.ipynb#Define-models" data-toc-modified-id="Define-models-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Define models</a></span></li><li><span><a href="http://localhost:8889/notebooks/17-fullres-ang-01.ipynb#Training" data-toc-modified-id="Training-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Training</a></span></li></ul></div>

# %% [markdown]
# # Load libraries

# %%
import cv2
import numpy as np
import pandas as pd

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, UpSampling2D, BatchNormalization
from keras.optimizers import RMSprop
from keras.losses import binary_crossentropy
import keras.backend as K

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
import math
import random
import gzip
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Define loss functions

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score


def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss


def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %% [markdown]
# # Define models

# %%
def unet_down_one_block(inputs, num_filters):
    x = Conv2D(num_filters, (3, 3), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def unet_max_pool(inputs):
    x = MaxPooling2D((2, 2), strides=(2, 2))(inputs)
    return x

# %%
def unet_up_one_block(up_input, down_input, num_filters):
    x = UpSampling2D((2,2))(up_input)
    x = concatenate([down_input, x], axis=3)
    x = Conv2D(num_filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def get_unet(input_shape = (256, 256, 3),
             num_classes = 1,
             initial_filters = 32,
             central_filters = 1024):
    
    num_filters = initial_filters
    
    out_list    = [Input(shape=input_shape)]
    down_interim_list = []
    
    while num_filters <= central_filters/2:
        x = unet_down_one_block(out_list[-1], num_filters)
        down_interim_list.append(x)
        num_filters = num_filters * 2
        y = unet_max_pool(x)
        out_list.append(y)
    
    x = unet_down_one_block(out_list[-1], num_filters)
    out_list.append(x)
    num_filters = int(num_filters / 2)
    
    while num_filters >= initial_filters:
        x = unet_up_one_block(out_list[-1], down_interim_list.pop(), num_filters)
        out_list.append(x)
        num_filters = int(num_filters / 2)
    
    classify = Conv2D(num_classes, (1,1), activation = 'sigmoid')(out_list[-1])
    
    model = Model(inputs=out_list[0], outputs=classify)
    
    return model

# %%
model = get_unet(input_shape=(1152,1152,3), initial_filters=8)

# %%
model.load_weights('./weights/best_weights_fullres3.hdf5')

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 1152, 1152, 3) 0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 1152, 1152, 8) 224         input_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 1152, 1152, 8) 32          conv2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 1152, 1152, 8) 0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 1152, 1152, 8) 584         activation_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 1152, 1152, 8) 32          conv2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 1152, 1152, 8) 0           batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 576, 576, 8)   0           activation_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 576, 576, 16)  1168        max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 576, 576, 16)  64          conv2d_3[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 576, 576, 16)  0           batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 576, 576, 16)  2320        activation_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 576, 576, 16)  64          conv2d_4[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 576, 576, 16)  0           batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 288, 288, 16)  0           activation_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 288, 288, 32)  4640        max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 288, 288, 32)  128         conv2d_5[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 288, 288, 32)  0           batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 288, 288, 32)  9248        activation_5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, 288, 288, 32)  128         conv2d_6[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 288, 288, 32)  0           batch_normalization_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 144, 144, 32)  0           activation_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 144, 144, 64)  18496       max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNorm (None, 144, 144, 64)  256         conv2d_7[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 144, 144, 64)  0           batch_normalization_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 144, 144, 64)  36928       activation_7[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNorm (None, 144, 144, 64)  256         conv2d_8[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 144, 144, 64)  0           batch_normalization_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 72, 72, 64)    0           activation_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 72, 72, 128)   73856       max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNorm (None, 72, 72, 128)   512         conv2d_9[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 72, 72, 128)   0           batch_normalization_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 72, 72, 128)   147584      activation_9[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10 (BatchNor (None,
train_bboxes = pickle.load(open('./train_bboxes_resized_m512_ang_01.pkl', 'rb'))

# %%
actual_bboxes = pickle.load(open('./train_bboxes_actuals.pkl', 'rb'))

# %%
ids_train = list(train_bboxes.keys())

# %%
ids_train_split, ids_valid_split = train_test_split(ids_train, test_size=0.2, random_state=42)

# %%
def randomHueSaturationValue(image, hue_shift_limit=(-180, 180),
                             sat_shift_limit=(-255, 255),
                             val_shift_limit=(-255, 255), u=0.5):
    if np.random.random() < u:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        h, s, v = cv2.split(image)
        hue_shift = np.random.uniform(hue_shift_limit[0], hue_shift_limit[1])
        h = cv2.add(h, hue_shift)
        sat_shift = np.random.uniform(sat_shift_limit[0], sat_shift_limit[1])
        s = cv2.add(s, sat_shift)
        val_shift = np.random.uniform(val_shift_limit[0], val_shift_limit[1])
        v = cv2.add(v, val_shift)
        image = cv2.merge((h, s, v))
        image = cv2.cvtColor(image, cv2.COLOR_HSV2BGR)

    return image

# %%
def randomShiftScaleRotate(image, mask,
                           shift_limit=(-0.0625, 0.0625),
                           scale_limit=(-0.1, 0.1),
                           rotate_limit=(-45, 45), aspect_limit=(0, 0),
                           borderMode=cv2.BORDER_CONSTANT, u=0.5):
    if np.random.random() < u:
        height, width, channel = image.shape

        angle = np.random.uniform(rotate_limit[0], rotate_limit[1])  # degree
        scale = np.random.uniform(1 + scale_limit[0], 1 + scale_limit[1])
        aspect = np.random.uniform(1 + aspect_limit[0], 1 + aspect_limit[1])
        sx = scale * aspect / (aspect ** 0.5)
        sy = scale / (aspect ** 0.5)
        dx = round(np.random.uniform(shift_limit[0], shift_limit[1]) * width)
        dy = round(np.random.uniform(shift_limit[0], shift_limit[1]) * height)

        cc = np.math.cos(angle / 180 * np.math.pi) * sx
        ss = np.math.sin(angle / 180 * np.math.pi) * sy
        rotate_matrix = np.array([[cc, -ss], [ss, cc]])

        box0 = np.array([[0, 0], [width, 0], [width, height], [0, height], ])
        box1 = box0 - np.array([width / 2, height / 2])
        box1 = np.dot(box1, rotate_matrix.T) + np.array([width / 2 + dx, height / 2 + dy])

        box0 = box0.astype(np.float32)
        box1 = box1.astype(np.float32)
        mat = cv2.getPerspectiveTransform(box0, box1)
        image = cv2.warpPerspective(image, mat, (width, height), flags=cv2.INTER_LINEAR, borderMode=borderMode,
                                    borderValue=(
                                        0, 0,
                                        0,))
        mask = cv2.warpPerspective(mask, mat, (width, height), flags=cv2.INTER_LINEAR, borderMode=borderMode,
                                   borderValue=(
                                       0, 0,
                                       0,))

    return image, mask

# %%
def randomHorizontalFlip(image, mask, u=0.5):
    if np.random.random() < u:
        image = cv2.flip(image, 1)
        mask = cv2.flip(mask, 1)

    return image, mask

# %%
all_imgs  = {}
all_masks = {}
for id in ids_train:
    img  = cv2.imread('data/train/{}.jpg'.format(id))
    mask = cv2.imread('data/train_masks/{}_mask.png'.format(id), cv2.IMREAD_GRAYSCALE)
    all_imgs[id]  = img
    all_masks[id] = mask

# %%
def train_generator(train_batch_size):
    while True:
        this_ids_train_split = random.sample(ids_train_split, len(ids_train_split))
        for start in range(0, len(ids_train_split), train_batch_size):
            x_batch = []
            y_batch = []
            end = min(start + train_batch_size, len(ids_train_split))
            ids_train_batch = this_ids_train_split[start:end]
            for id in ids_train_batch:
                img  = all_imgs[id]
                mask = all_masks[id]
                
                this_bbox = train_bboxes[id]
                this_bbox = [math.floor(this_bbox[0]-15), math.ceil(this_bbox[1]+15),
                             math.floor(this_bbox[2]-25), math.ceil(this_bbox[3]+25)]
                
                x_size = this_bbox[1]-this_bbox[0]+1
                y_size = this_bbox[3]-this_bbox[2]+1
                
                x_diff=1152-x_size
                y_diff=1152-y_size
                
                x_top=random.randint(0, min(x_diff, this_bbox[0]))
                x_bottom=min(x_diff-x_top, 1917-this_bbox[1])
                if (x_top+x_bottom) < x_diff:
                    if x_top==this_bbox[0]:
                        x_bottom = x_diff-x_top
                    else:
                        x_top = x_diff-x_bottom
                
                
                y_top=random.randint(0, min(y_diff, this_bbox[2]))
                y_bottom=min(y_diff-y_top, 1279-this_bbox[3])
                if (y_top+y_bottom) < y_diff:
                    if y_top==this_bbox[2]:
                        y_bottom = y_diff-y_top
                    else:
                        y_top = y_diff-y_bottom
                
                this_bbox[0] = this_bbox[0]-x_top
                this_bbox[1] = this_bbox[1]+x_bottom
                this_bbox[2] = this_bbox[2]-y_top
                this_bbox[3] = this_bbox[3]+y_bottom
                
                img  = img[this_bbox[2]:(this_bbox[3]+1), this_bbox[0]:(this_bbox[1]+1),:]
                mask = mask[this_bbox[2]:(this_bbox[3]+1), this_bbox[0]:(this_bbox[1]+1)]
                
                img = randomHueSaturationValue(img,
                                               hue_shift_limit=(-50, 50),
                                               sat_shift_limit=(-5, 5),
                                               val_shift_limit=(-15, 15))
                img, mask = randomHorizontalFlip(img, mask)
                mask = np.expand_dims(mask, axis=2)
                
                x_batch.append(img)
                y_batch.append(mask)
                
            x_batch = np.array(x_batch, np.float32) / 255
            y_batch = np.array(y_batch, np.float32) / 255
            yield x_batch, y_batch

# %%
def valid_generator(val_batch_size):
    while True:
        for start in range(0, len(ids_valid_split), val_batch_size):
            
            x_batch = []
            y_batch = []
            
            end = min(start + val_batch_size, len(ids_valid_split))
            ids_valid_batch = ids_valid_split[start:end]
            for id in ids_valid_batch:
                img  = all_imgs[id]
                mask = all_masks[id]
                
                this_bbox = list(actual_bboxes[id])
                
                x_size = this_bbox[1]-this_bbox[0]+1
                y_size = this_bbox[3]-this_bbox[2]+1
                
                x_diff=1152-x_size
                y_diff=1152-y_size
                
                x_top=min(int(x_diff/2), this_bbox[0])
                x_bottom=min(x_diff-x_top, 1917-this_bbox[1])
                if (x_top+x_bottom) < x_diff:
                    if x_top==this_bbox[0]:
                        x_bottom = x_diff-x_top
                    else:
                        x_top = x_diff-x_bottom
                
                y_top=min(int(y_diff/2), this_bbox[2])
                y_bottom=min(y_diff-y_top, 1279-this_bbox[3])
                if (y_top+y_bottom) < y_diff:
                    if y_top==this_bbox[2]:
                        y_bottom = y_diff-y_top
                    else:
                        y_top = y_diff-y_bottom
                
                this_bbox[0] = this_bbox[0]-x_top
                this_bbox[1] = this_bbox[1]+x_bottom
                this_bbox[2] = this_bbox[2]-y_top
                this_bbox[3] = this_bbox[3]+y_bottom
                
                img  = img[this_bbox[2]:(this_bbox[3]+1), this_bbox[0]:(this_bbox[1]+1),:]
                mask = mask[this_bbox[2]:(this_bbox[3]+1), this_bbox[0]:(this_bbox[1]+1)]
                
                mask = np.expand_dims(mask, axis=2)
                
                x_batch.append(img)
                y_batch.append(mask)  
            x_batch = np.array(x_batch, np.float32) / 255
            y_batch = np.array(y_batch, np.float32) / 255
            yield x_batch, y_batch

# %%
train_batch_size = 6
val_batch_size   = 16

# %%
model.compile(optimizer=RMSprop(lr=0.001), loss=bce_dice_loss, metrics=[dice_coeff])

# %%
model.evaluate_generator(valid_generator(val_batch_size), np.ceil(float(len(ids_valid_split)) / float(val_batch_size)))
# Out:
# [0.13471121713519096, 0.96814502775669098]

# %%
model.fit_generator(generator=train_generator(train_batch_size),
                    steps_per_epoch=np.ceil(float(len(ids_train_split)) / float(train_batch_size)),
                    epochs=1,
                    verbose=2,
                    validation_data=valid_generator(val_batch_size),
                    validation_steps=np.ceil(float(len(ids_valid_split)) / float(val_batch_size)))
# Out:
# Epoch 1/1
# 192s - loss: 0.3097 - dice_coeff: 0.9141 - val_loss: 11.5321 - val_dice_coeff: 0.4708

# %%
max_epochs = 50

# %%
model.compile(optimizer=RMSprop(lr=0.0001), loss=bce_dice_loss, metrics=[dice_coeff])

# %%
callbacks = [EarlyStopping(monitor='val_loss',
                           patience=8,
                           verbose=1,
                           min_delta=1e-4),
             ReduceLROnPlateau(monitor='val_loss',
                               factor=0.1,
                               patience=4,
                               verbose=1,
                               epsilon=1e-4),
             ModelCheckpoint(monitor='val_loss',
                             filepath='weights/full_res_ang_01.hdf5',
                             save_best_only=True,
                             save_weights_only=True),
             TensorBoard(log_dir='logs')]

history = model.fit_generator(generator=train_generator(train_batch_size),
                    steps_per_epoch=np.ceil(float(len(ids_train_split)) / float(train_batch_size)),
                    epochs=max_epochs,
                    verbose=2,
                    callbacks=callbacks,
                    validation_data=valid_generator(val_batch_size),
                    validation_steps=np.ceil(float(len(ids_valid_split)) / float(val_batch_size)))
# Out:
# Epoch 1/50
# 185s - loss: 0.0417 - dice_coeff: 0.9830 - val_loss: 2.7337 - val_dice_coeff: 0.6881
# Epoch 2/50
# 181s - loss: 0.0246 - dice_coeff: 0.9898 - val_loss: 0.1500 - val_dice_coeff: 0.9560
# Epoch 3/50
# 181s - loss: 0.0179 - dice_coeff: 0.9923 - val_loss: 0.1517 - val_dice_coeff: 0.9532
# Epoch 4/50
# 182s - loss: 0.0156 - dice_coeff: 0.9934 - val_loss: 0.0143 - val_dice_coeff: 0.9935
# Epoch 5/50
# 182s - loss: 0.0143 - dice_coeff: 0.9940 - val_loss: 0.0142 - val_dice_coeff: 0.9935
# Epoch 6/50
# 182s - loss: 0.0125 - dice_coeff: 0.9947 - val_loss: 0.0159 - val_dice_coeff: 0.9929
# Epoch 7/50
# 182s - loss: 0.0116 - dice_coeff: 0.9950 - val_loss: 0.0137 - val_dice_coeff: 0.9938
# Epoch 8/50
# 182s - loss: 0.0113 - dice_coeff: 0.9951 - val_loss: 0.0149 - val_dice_coeff: 0.9935
# Epoch 9/50
# 182s - loss: 0.0108 - dice_coeff: 0.9954 - val_loss: 0.0118 - val_dice_coeff: 0.9946
# Epoch 10/50
# 182s - loss: 0.0107 - dice_coeff: 0.9954 - val_loss: 0.0162 - val_dice_coeff: 0.9931
# Epoch 11/50
# 181s - loss: 0.0102 - dice_coeff: 0.9956 - val_loss: 0.0234 - val_dice_coeff: 0.9901
# Epoch 12/50
# 182s - loss: 0.0098 - dice_coeff: 0.9957 - val_loss: 0.0115 - val_dice_coeff: 0.9949
# Epoch 13/50
# 182s - loss: 0.0098 - dice_coeff: 0.9958 - val_loss: 0.0165 - val_dice_coeff: 0.9934
# Epoch 14/50
# 182s - loss: 0.0094 - dice_coeff: 0.9959 - val_loss: 0.0125 - val_dice_coeff: 0.9948
# Epoch 15/50
# 182s - loss: 0.0095 - dice_coeff: 0.9959 - val_loss: 0.0121 - val_dice_coeff: 0.9950
# Epoch 16/50
# 181s - loss: 0.0092 - dice_coeff: 0.9960 - val_loss: 0.0119 - val_dice_coeff: 0.9952
# Epoch 17/50
# 182s - loss: 0.0095 - dice_coeff: 0.9959 - val_loss: 0.0108 - val_dice_coeff: 0.9955
# Epoch 18/50
# 182s - loss: 0.0093 - dice_coeff: 0.9960 - val_loss: 0.0122 - val_dice_coeff: 0.9949
# Epoch 19/50
# 182s - loss: 0.0089 - dice_coeff: 0.9961 - val_loss: 0.0109 - val_dice_coeff: 0.9952
# Epoch 20/50
# 182s - loss: 0.0089 - dice_coeff: 0.9961 - val_loss: 0.0106 - val_dice_coeff: 0.9955
# Epoch 21/50
# 181s - loss: 0.0086 - dice_coeff: 0.9962 - val_loss: 0.0113 - val_dice_coeff: 0.9954
# Epoch 22/50
# 182s - loss: 0.0086 - dice_coeff: 0.9963 - val_loss: 0.0110 - val_dice_coeff: 0.9955
# Epoch 23/50
# 182s - loss: 0.0096 - dice_coeff: 0.9960 - val_loss: 0.0103 - val_dice_coeff: 0.9956
# Epoch 24/50
# 182s - loss: 0.0081 - dice_coeff: 0.9964 - val_loss: 0.0105 - val_dice_coeff: 0.9957
# Epoch 25/50
# 182s - loss: 0.0085 - dice_coeff: 0.9963 - val_loss: 0.0108 - val_dice_coeff: 0.9956
# Epoch 26/50
# 182s - loss: 0.0084 - dice_coeff: 0.9963 - val_loss: 0.0105 - val_dice_coeff: 0.9956
# Epoch 27/50
# 182s - loss: 0.0082 - dice_coeff: 0.9964 - val_loss: 0.0107 - val_dice_coeff: 0.9956
# Epoch 28/50
#
# Epoch 00027: reducing learning rate to 9.999999747378752e-06.
# 182s - loss: 0.0082 - dice_coeff: 0.9964 - val_loss: 0.0110 - val_dice_coeff: 0.9956
# Epoch 29/50
# 182s - loss: 0.0082 - dice_coeff: 0.9964 - val_loss: 0.0099 - val_dice_coeff: 0.9960
# Epoch 30/50
